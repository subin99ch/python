# %% [markdown]
# #1. 변수
# * 영문 문자와 숫자를 사용할 수 있습니다. ex)a1,a2 가능
# * 대소문자를 구분합니다.
# * 문자부터 시작해야 하며 숫자로 시작하면 안됩니다. ex)2a/3a-> X
# *_(under_bar)로 시작할 수 있음
# *특수문자(+,-,*,$,...)은 변수로 사용할 수 없음
# *파이썬 예약어(if, for while, and, or)등은 변수이름으로 사용할 수 없음
# * #은 주석

# %%
a=3

# %%
print(a)

# %%
a=4

# %%
print(a)

# %%
print('Hello world')

# %%
a=5
A=6
print(a)
print(A)

# %%
_a=7
print(_a)

# %%
import keyword
python_keyword=keyword.kwlist
print(python_keyword)
len(python_keyword)

# %%
#id는 주소값을 나타내는 함수
var1="Hello python"
print(var1)
print(id(var1))

# %%
var1=100
print(var1)
print(id(var1))

# %%
var2=150.25
print(var2)
print(id(var2))

# %% [markdown]
# *print()함수의 다양한 사용

# %%
#출력 print(value1,value2,....)
print('Hello world')  #변수 1개 
print('Hello', 'world') #변수 2개

# %%
print('홍길동', '김철수',sep=', ') #sep 구분

# %%
print('1+1=',1+1) #(문자, 값)
print('1+1',1+1,sep='=')

# %%
food="python's favorite food is perl"
food1= "python's favortie food is perl"

print(food)
print(food1)

# %%
say= 'python is very easy, he says'
say1='"python is very easy", he says'
say2='\'python's very easy',\ he says'
print(say)
print(say1)
print(say2)

# %%
#type()
var3="Hello python"
print(var3)
print(type(var3))
#str=string=문자열

# %%
var4=100
print(var4)
print(type(var4)) #int=integer = 정수

# %%
var5=150.3
print(var5)
print(type(var5)) #float = 실수

# %%
var6=True
print(var6)
print(type(var6)) #boolen = 참 또는 거짓

# %% [markdown]
# ##자료형 변환

# %%
a=int(10.5)
print(a)
print(type(a))

# %%
b=float(20)
print(b)
print(type(b))

# %%
print(type(True))
print(int(True))

# %%
print(type(True))
print(int(True))
print(int(False))

# %%
st1 = "10.5"  #문자 X/ 2번 형변환은 안됨?
print(type(st1))
st2=float(st1)
print(int(st2))

# %%
c=100.22
print(type(str(c)))

# %% [markdown]
# #연산자
# p.39

# %%
'''연산자(operator)
1. 산술연산자
2. 관계연산자
3. 논리연산자
4. 대입연산자
'''
# Out:
# '연산자(operator)\n1. 산술연산자\n2. 관계연산자\n3. 논리연산자\n4. 대입연산자\n'

# %%
#1.산술연산자
num1=100
num2=20
add1= num1+num2
print(add1)
print(type(add1))
# Out:
# 120
# <class 'int'>

# %%
sub=num1-num2
print(sub)
# Out:
# 80

# %%
mul=num1*num2
print(mul)
# Out:
# 2000

# %%
div1=num1/num2
print(div1)
# Out:
# 5.0

# %%
div2=num1//num2 # 몫을 정수만 반환
print(div2)
# Out:
# 5

# %%
num3=7
num4=4
div3= num3 % num4 #3나머지
print(div3)
# Out:
# 3

# %%
sq=num4 ** 3 #**<=제곱근
sq2=num3 ** 2
print(sq)
print(sq2)
# Out:
# 64
# 49

# %% [markdown]
# ##h 관계연산자

# %%
#1) 동등비교
bool_result=num1==num2 # 두 변수의 값이 같은지 비교
print(bool_result)
# Out:
# False

# %%
bool_result2=num1!=num2 #두 변수의 값이 다른지 비교
print(bool_result2)
# Out:
# True

# %%
#(2) 크기 비교
bool_result3= num1>num2
print(bool_result3)
# Out:
# False

# %% [markdown]
# #문제

# %%
# 시가총액 298조, 현재가 50,000, per 15.79을 변수에 넣어서 타입 찍어보기
시가총액 = 29800000000000
현재가 = 50000
per=15.79
print(시가총액, type(시가총액))
print(시가총액, type(현재가))
print(per, type(per))
# Out:
# 29800000000000 <class 'int'>
# 29800000000000 <class 'int'>
# 15.79 <class 'float'>

# %%
# 에어컨이 월 48,584원에 무이자 36개월의 조건으로 홈쇼핑에 판매되고 있습니다. 총 금액은 계산한 후 이를 화면에 출력해보세요. (변수 사용하기)
월= 48584
총금액=월*36
print(총금액)
# Out:
# 1749024

# %% [markdown]
# #논리연산자

# %%
#and 조건
num1=100
num2=20
log_result = num1> 50 and num2 <= 10 #참 거짓 #and:참참->참/참거짓->거짓
print(log_result)
# Out:
# False

# %%
log_result2 = num1> 50 and num2 >= 10 #참 참
print(log_result2)
# Out:
# True

# %%
log_result3 = num1< 50 and num2 <= 10 #거짓 거짓
print(log_result3)
# Out:
# False

# %%
#or 조건
num1=100
num2=20
log_result5 = num1> 50 or num2 <= 10 #참 거짓 
print(log_result5)
# Out:
# True

# %%
log_result6 = num1> 50 or num2 >= 10 #참 참
print(log_result6)
# Out:
# True

# %%
log_result7 = num1< 50 or num2 <= 10 #거짓 거짓
print(log_result7)
# Out:
# False

# %%
#not 
log_result9=not(num1 <=50) # 반대
print(log_result9)
# Out:
# True

# %% [markdown]
# #대입연산자

# %%
# 1)변수에 값을 할당(=)
i= tot = 10
print(i, tot)
# Out:
# 10 10

# %%
tot1=10
i1=tot1
print(i1, tot)
# Out:
# 10 10

# %%
i=i+1
print(i)
# Out:
# 11

# %%
i +=1
print(i)
# Out:
# 12

# %%
tot += i #tot=tot + i
print(tot) #22
# Out:
# 22

# %%
v1, v2 = 100,200
print(v1)
print(v2)
# Out:
# 100
# 200

# %%
v1, v2=v2, v1
print(v1) #200
print(v2) #100
# Out:
# 200
# 100

# %%
x=y=z=10
print(x,y,z)
# Out:
# 10 10 10

# %%
del z #delete의 약자

# %%
print(x,y)
# Out:
# 10 10

# %%
print(z) #변수가 없기 때문에 출력도 불가
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-7615871910c2> in <module>
# ----> 1 print(z) #변수가 없기 때문에 출력도 불가
#
# NameError: name 'z' is not defined

# %% [markdown]
# #표준입력장치

# %%
num= input()  #표준입력장치는 문자로 형변환
# Out:
# 100

# %%
print(num)
# Out:
# 100

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
a= int(num) #문자열-) 정수열

# %%
print(type(a))
print(a)
# Out:
# <class 'int'>
# 100

# %%
num2=int(input())
print(type(num2))
print(num2)
# Out:
# 100
# <class 'int'>
# 100

# %%
num3=float(input())
print(type(num3))
print(num3)
# Out:
# 2
# <class 'float'>
# 2.0

# %%
num4=int(float(input()))  
print(type(num4))
print(num4)
# Out:
# 36.9
# <class 'int'>
# 36

# %%
num5=int(10.235)  #강제 형변환
num5=float(num5)
num6=int(num5)
print(type(num6))
print(num6)
# Out:
# <class 'int'>
# 10

# %%
num7=int(input("정수만 입력하세요 : "))
print(type(num7))
print(num7)
# Out:
# 정수만 입력하세요 : 5
# <class 'int'>
# 5

# %%
n1=int(input("정수만:"))
n2=int(input("정수만:"))
print(n1+n2)
# Out:
# 정수만:53
# 정수만:63
# 116

# %% [markdown]
# #표준출력장치

# %%
# format(value, '양식)
help(format) #도움말
# Out:
# Help on built-in function format in module builtins:
#
# format(value, format_spec='', /)
#     Return value.__format__(format_spec)
#
#     format_spec defaults to the empty string.
#     See the Format Specification Mini-Language section of help('FORMATTING') for
#     details.

# %% [markdown]
# #format과 양식문자

# %%
'''
%양식문자
# %s : 문자열
# %c ; 한개문자
# %d : 정수
# %f : 실수
# %o : 8 진수
# %x : 16진수
%% : %출력
'''
# Out:
# '\n%양식문자\n%s : 문자열\n%c ; 한개문자\n%d : 정수\n%f : 실수\n%o : 8 진수\n%x : 16진수\n%% : %출력\n'

# %%
print('원주율=', 3.14159)
# Out:
# 원주율= 3.14159

# %%
print('원주율=', format(3.14159, ".3f")) #foramt(value, '양식')/3f->소수점 아래 3자리 까지
# Out:
# 원주율= 3.142

# %%
x=3.14159  #축약형
print(f'원주율={x:.2f}')
# Out:
# 원주율=3.14

# %% [markdown]
# ##########3가지 방식 기억

# %%
print('금액=', format(100000,'3,d'))
# Out:
# 금액= 100,000

# %%
print('금액=', format(1000000000000000, "3,d")) #<-여기서 3은 공백여백으ㅣ 수
# Out:
# 금액= 1,000,000,000,000,000

# %%
print(f'금액 = {10000: 10,}')
# Out:
# 금액 =     10,000

# %%
#3)외부상수받기
name='홍길동'
age=25
tall=175.456
print('이름:,%s, 나이:%d, data=%.2f'%(name, age, tall))
# Out:
# 이름:,홍길동, 나이:25, data=175.46

# %%
print('이름:{}, 나이:{}, data{}'.format(name, age, tall))
# Out:
# 이름:홍길동, 나이:25, data175.456

# %%
#축약형 f-string
print(f'이름:{name}, 나이:{age}, data: {tall}')
# Out:
# 이름:홍길동, 나이:25, data: 175.456

# %% [markdown]
# 참고사항

# %%
# 변수를 만들때 3가지 방법
# camel 표기법, snake 표기법, pascal 표기법
camelCase = 1
snake_case = 1
PascalCase = 1

# %% [markdown]
# #문자열

# %%
multiline = "Life is too short \n You need python" # \n : enter
print(multiline)
# Out:
# Life is too short
#  You need python

# %%
multiline2='''
여러줄의
문장을
한번에 포함 시킬수 있음
'''
print(multiline2)
# Out:
# 여러줄의
# 문장을
# 한번에 포함 시킬수 있음

# %%
head = 'python'
tail = '    is fun!'
print(head + tail)   #문자내에서의 +, * 만 가능
# Out:
# python    is fun!

# %%
a= "Life is too short \n You need python"
a[3] #인덱싱(색인) : 0번째부터 셈 p. 49
# Out:
# 'e'

# %%
a[12]
# Out:
# 's'

# %%
a[-1]
# Out:
# 'n'

# %%
a[-5]

# %%
a = "Life is too short, You need python"
print(a[5:-1])
print(a[5:-1:2])      #<-2자리는 간격자리
# Out:
# is too short, You need pytho
# i o hr,Yune yh

# %%
a[0:4] # n-1
# Out:
# 'Life'

# %%
#   a[처음:끝번호(n-1):간격]

# %%
a = '20230307Rainy'
date = a[:8:]
weather = a[8:]
print(date)
print(weather)
# Out:
# 20230307
# Rainy

# %%
#음수만 슬라이싱
b= 'Hello world'
# Hello
# world

# %%
print(b[:-6])
print(b[-5:])
# Out:
# Hello
# world

# %%
# 역순으로 -> 간격부분에 -1 
print(b[::-1])
# Out:
# dlrow olleH

# %% [markdown]
# COUNT 함수

# %%
a  = 'hobby'
a.count('b')
# Out:
# 2

# %%
a = 'Python is best program'
a.find('b')
# Out:
# 10

# %%
a.find('k') # 찾는 문자가 없으면 -1
# Out:
# -1

# %%
a.index('b')
# Out:
# 10

# %% [markdown]
# a.find 는 없으면 -1 /
# a.index는 없으면 error

# %% [markdown]
# Join 함수

# %%
'/'.join('abcedfg') # ' ' 구분자 (, / 공백 가능)
# Out:
# 'a/b/c/e/d/f/g'

# %%
g = ','
g.join('abcdef')
# Out:
# 'a,b,c,d,e,f'

# %% [markdown]
# ###다른 함수

# %%
a = 'Python is best program'
a.upper ()
# Out:
# 'PYTHON IS BEST PROGRAM'

# %%
a.lower()
# Out:
# 'python is best program'

# %%
a = "    Hi      "
a.strip()  #공백제거,  rstrip 오른쪽 공백제거  lstrip  왼쪽 공백제거
# Out:
# 'Hi'

# %%
 a = 'Java is best program'
 a.replace('Java', 'Python')  # replace 문자 변경
# Out:
# 'Python is best program'

# %%
a.split()  # split (구분자) 문자 분리
# Out:
# ['Java', 'is', 'best', 'program']

# %%
a = 'a:b:c:d'
a.split(':')
# Out:
# ['a', 'b', 'c', 'd']

# %%
phone = '010-1234-5678'
phone.split('-')
# Out:
# ['010', '1234', '5678']

# %%
email = 'abcd@naver.com'
email.split('@')
# Out:
# ['abcd', 'naver.com']

# %% [markdown]
# Quiz. 1.['naver', 'com']
#
# 2. letter = 'python'   -> p t
# 3. string = '홀짝홀짝홀짝' -> 홀홀홀
# 4. 표준입력장치로 사용장의 영문이름을 입력받아서 성과 이름을 순서를 바꾸어 출력하는 프로그램을 작성 (hong gildong / gildong hong)

# %%
#1
email = 'abcd@naver.com'
b = email.split('@')
b[1].split('.')
# Out:
# ['naver', 'com']

# %%
#2
letter = 'python'
print(letter[0], letter[2])
# Out:
# p t

# %%
#3
string = '홀짝홀짝홀짝'
print(string[::2]) #?
# Out:
# 홀홀홀

# %%
#4
full_name=(input('영문이름입력(성과 이름은 공백으로 구분) :'))
full_name.split(' ')
# Out:
# 영문이름입력(성과 이름은 공백으로 구분) :hong gildong
# ['hong', 'gildong']

# %%
first_name2 = full_name.split()[0]
last_name2 = full_name.split()[1]
print(last_name2)
print(first_name2)
# Out:
# gildong
# hong

# %% [markdown]
# 또 다른 방법

# %%
space = full_name.find(' ')

# %%
print(space)
# Out:
# 4

# %%
first_name=full_name[:space]
last_name=full_name[space+1:]
print(last_name, first_name)
# Out:
# gildong hong

# %% [markdown]
# 또 다른 방법?

# %%
full_name.capitalize()
# Out:
# 'Hong gildong'

# %% [markdown]
# #Escape 문자
# p. 54

# %%
print('escape 문자 차단')
# 경로표현
print('paith =', 'c:\python38\test')  # \t \n 은 짤릴 수 있음
print('paith =', 'c:\\python38\\test')  # \\을 써서 차단
print('paith =', r'c:\python38\test\naver') # r을 써서 차단(r 뒤에 있는 문구들이 그대로 출력)
# Out:
# escape 문자 차단
# paith = c:\python38	est
# paith = c:\python38\test
# paith = c:\python38\test\naver

# %%
#1 신씨가 소리질렀다. "도둑이야"
#2 c:\windows\naver\test
#3. naver / kakao/sk/samsung
#4. station = '신촌', door = '왼쪽'
#  이번역은 신촌역입니다. 내리실문은 왼쪽입니다

# %%
print('신씨가 소리질렀다. "도둑이야"')
# Out:
# 신씨가 소리질렀다. "도둑이야"

# %%
print('paith =', r'c:\windows\naver\test')
# Out:
# paith = c:\windows\naver\test

# %%
qj = 'naver kakao sk samsung'
qj.replace(' ', '/')
# Out:
# 'naver/kakao/sk/samsung'

# %%
print("naver", "kakao", "sk", "samsung", sep='/')
# Out:
# naver/kakao/sk/samsung

# %%
station = '신촌'
door = '왼쪽'
print(f'이번역은 {station}역입니다. 내리실문은 {door}입니다.')  #f를 넣어야지 출력
# Out:
# 이번역은 신촌역입니다. 내리실문은 왼쪽입니다.
